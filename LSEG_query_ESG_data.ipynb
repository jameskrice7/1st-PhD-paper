# %%
import eikon as ek
import pandas as pd

# Replace with your own App Key
ek.set_app_key('5d67b807cafe47c0acf2248d6f56ec409013c511')

# %%
import warnings
warnings.filterwarnings("ignore", message=".*errors='ignore'.*")


# Example: MSCI World constituents
CHAIN_RIC = "0#.SPX"

# Retrieve RICs from the index chain
constituents, err = ek.get_data(CHAIN_RIC, ["RIC", "CompanyName"])
if err:
    print("Error retrieving chain RIC constituents:", err)
else:
    print(f"Number of constituents retrieved: {len(constituents)}")
    print(constituents.head(10))
# Out:
# Error retrieving chain RIC constituents: [{'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'POOL.OQ'", 'row': 0}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'POOL.OQ'", 'row': 0}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'CHRW.OQ'", 'row': 1}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'CHRW.OQ'", 'row': 1}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'AJG.N'", 'row': 2}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'AJG.N'", 'row': 2}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'CNP.N'", 'row': 3}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'CNP.N'", 'row': 3}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'AMCR.N'", 'row': 4}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'AMCR.N'", 'row': 4}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'WM.N'", 'row': 5}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'WM.N'", 'row': 5}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'BA.N'", 'row': 6}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'BA.N'", 'row': 6}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'FOX.OQ'", 'row': 7}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'FOX.OQ'", 'row': 7}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'TKO.N'", 'row': 8}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'TKO.N'", 'row': 8}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'WY.N'", 'row': 9}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'WY.N'", 'row': 9}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'MCD.N'", 'row': 10}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'MCD.N'", 'row': 10}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'HD.N'", 'row': 11}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'HD.N'", 'row': 11}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'SPG.N'", 'row': 12}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'SPG.N'", 'row': 12}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'HBAN.OQ'", 'row': 13}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'HBAN.OQ'", 'row': 13}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'LVS.N'", 'row': 14}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'LVS.N'", 'row': 14}, {'code': 2 ...

# %%
chains = ["0#.SPX", "0#.DJI", "0#.FTSE", "0#.STOXX50E", "0#.N225", "0#.HSI"]
for chain_ric in chains:
    df, err = ek.get_data(chain_ric, ["RIC", "CompanyName"])
    if err:
        print(f"{chain_ric} -> Error:", err)
    else:
        print(f"{chain_ric} -> Success, retrieved {len(df)} constituents")
# Out:
# 0#.SPX -> Error: [{'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'POOL.OQ'", 'row': 0}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'POOL.OQ'", 'row': 0}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'CHRW.OQ'", 'row': 1}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'CHRW.OQ'", 'row': 1}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'AJG.N'", 'row': 2}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'AJG.N'", 'row': 2}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'CNP.N'", 'row': 3}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'CNP.N'", 'row': 3}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'AMCR.N'", 'row': 4}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'AMCR.N'", 'row': 4}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'WM.N'", 'row': 5}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'WM.N'", 'row': 5}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'BA.N'", 'row': 6}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'BA.N'", 'row': 6}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'FOX.OQ'", 'row': 7}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'FOX.OQ'", 'row': 7}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'TKO.N'", 'row': 8}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'TKO.N'", 'row': 8}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'WY.N'", 'row': 9}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'WY.N'", 'row': 9}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'MCD.N'", 'row': 10}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'MCD.N'", 'row': 10}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'HD.N'", 'row': 11}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'HD.N'", 'row': 11}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'SPG.N'", 'row': 12}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'SPG.N'", 'row': 12}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'HBAN.OQ'", 'row': 13}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'HBAN.OQ'", 'row': 13}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'LVS.N'", 'row': 14}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'LVS.N'", 'row': 14}, {'code': 251658244, 'col': 1, 'mes ...
# 0#.DJI -> Error: [{'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'GS.N'", 'row': 0}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'GS.N'", 'row': 0}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'NKE.N'", 'row': 1}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'NKE.N'", 'row': 1}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'CSCO.OQ'", 'row': 2}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'CSCO.OQ'", 'row': 2}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'JPM.N'", 'row': 3}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'JPM.N'", 'row': 3}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'DIS.N'", 'row': 4}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'DIS.N'", 'row': 4}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'MRK.N'", 'row': 5}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'MRK.N'", 'row': 5}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'CVX.N'", 'row': 6}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'CVX.N'", 'row': 6}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'AXP.N'", 'row': 7}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'AXP.N'", 'row': 7}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'SHW.N'", 'row': 8}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'SHW.N'", 'row': 8}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'VZ.N'", 'row': 9}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'VZ.N'", 'row': 9}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'HD.N'", 'row': 10}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'HD.N'", 'row': 10}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'MCD.N'", 'row': 11}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'MCD.N'", 'row': 11}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'UNH.N'", 'row': 12}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'UNH.N'", 'row': 12}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'AMZN.OQ'", 'row': 13}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'AMZN.OQ'", 'row': 13}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'KO.N'", 'row': 14}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'KO.N'", 'row': 14}, {'code': 251658244, 'col': 1, 'message': " ...
# 0#.FTSE -> Error: [{'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'STAN.L'", 'row': 0}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'STAN.L'", 'row': 0}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'CCEPC.L'", 'row': 1}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'CCEPC.L'", 'row': 1}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'CRDA.L'", 'row': 2}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'CRDA.L'", 'row': 2}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'ANTO.L'", 'row': 3}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'ANTO.L'", 'row': 3}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'EZJ.L'", 'row': 4}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'EZJ.L'", 'row': 4}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'BNZL.L'", 'row': 5}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'BNZL.L'", 'row': 5}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'SGE.L'", 'row': 6}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'SGE.L'", 'row': 6}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'SVT.L'", 'row': 7}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'SVT.L'", 'row': 7}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'LMPL.L'", 'row': 8}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'LMPL.L'", 'row': 8}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'ICAG.L'", 'row': 9}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'ICAG.L'", 'row': 9}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'REL.L'", 'row': 10}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'REL.L'", 'row': 10}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'SMIN.L'", 'row': 11}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'SMIN.L'", 'row': 11}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'BAB.L'", 'row': 12}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'BAB.L'", 'row': 12}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'AZN.L'", 'row': 13}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'AZN.L'", 'row': 13}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'HSBA.L'", 'row': 14}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'HSBA.L'", 'row': 14}, {'code': 251658244, ' ...
# 0#.STOXX50E -> Error: [{'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'DHLn.DE'", 'row': 0}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'DHLn.DE'", 'row': 0}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'PERP.PA'", 'row': 1}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'PERP.PA'", 'row': 1}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'NDAFI.HE'", 'row': 2}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'NDAFI.HE'", 'row': 2}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'AIRP.PA'", 'row': 3}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'AIRP.PA'", 'row': 3}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'IBE.MC'", 'row': 4}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'IBE.MC'", 'row': 4}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'SIEGn.DE'", 'row': 5}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'SIEGn.DE'", 'row': 5}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'SAN.MC'", 'row': 6}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'SAN.MC'", 'row': 6}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'VOWG_p.DE'", 'row': 7}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'VOWG_p.DE'", 'row': 7}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'SAPG.DE'", 'row': 8}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'SAPG.DE'", 'row': 8}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'CRDI.MI'", 'row': 9}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'CRDI.MI'", 'row': 9}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'AD.AS'", 'row': 10}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'AD.AS'", 'row': 10}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'BNPP.PA'", 'row': 11}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'BNPP.PA'", 'row': 11}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'DTEGn.DE'", 'row': 12}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'DTEGn.DE'", 'row': 12}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'SASY.PA'", 'row': 13}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument 'SASY.PA'", 'row': 13}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument 'ESLX.PA'", 'row': 14}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument ...
# 0#.N225 -> Error: [{'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '6857.T'", 'row': 0}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '6857.T'", 'row': 0}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '8267.T'", 'row': 1}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '8267.T'", 'row': 1}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '5201.T'", 'row': 2}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '5201.T'", 'row': 2}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '2802.T'", 'row': 3}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '2802.T'", 'row': 3}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '6770.T'", 'row': 4}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '6770.T'", 'row': 4}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '6113.T'", 'row': 5}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '6113.T'", 'row': 5}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '9202.T'", 'row': 6}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '9202.T'", 'row': 6}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '8304.T'", 'row': 7}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '8304.T'", 'row': 7}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '2502.T'", 'row': 8}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '2502.T'", 'row': 8}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '3407.T'", 'row': 9}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '3407.T'", 'row': 9}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '4503.T'", 'row': 10}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '4503.T'", 'row': 10}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '7832.T'", 'row': 11}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '7832.T'", 'row': 11}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '6532.T'", 'row': 12}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '6532.T'", 'row': 12}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '5108.T'", 'row': 13}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '5108.T'", 'row': 13}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '7751.T'", 'row': 14}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '7751.T'", 'row': 14}, {'code': 25 ...
# 0#.HSI -> Error: [{'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '2688.HK'", 'row': 0}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '2688.HK'", 'row': 0}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '2388.HK'", 'row': 1}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '2388.HK'", 'row': 1}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '2318.HK'", 'row': 2}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '2318.HK'", 'row': 2}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '9618.HK'", 'row': 3}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '9618.HK'", 'row': 3}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '0941.HK'", 'row': 4}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '0941.HK'", 'row': 4}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '9999.HK'", 'row': 5}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '9999.HK'", 'row': 5}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '2331.HK'", 'row': 6}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '2331.HK'", 'row': 6}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '0175.HK'", 'row': 7}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '0175.HK'", 'row': 7}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '6618.HK'", 'row': 8}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '6618.HK'", 'row': 8}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '0002.HK'", 'row': 9}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '0002.HK'", 'row': 9}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '0388.HK'", 'row': 10}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '0388.HK'", 'row': 10}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '0003.HK'", 'row': 11}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '0003.HK'", 'row': 11}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '9988.HK'", 'row': 12}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '9988.HK'", 'row': 12}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '1113.HK'", 'row': 13}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '1113.HK'", 'row': 13}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'RIC' was not found in response for the instrument '0968.HK'", 'row': 14}, {'code': 251658244, 'col': 2, 'message': "Error: Field 'COMPANYNAME' was not found in response for the instrument '0968. ...

# %%
# Step 1: Use a simpler set of fields
screen_expr = (
    'SCREEN('
    'U(IN(Equity(active,public,primary))/*UNV:Public*/),'
    'IN(TR.RegCountryCode,"US"),'
    'TR.TRESGScore(Period=FY0)>0,'
    'CURN=USD)'
)

universe_df, err = ek.get_data(
    screen_expr, 
    fields=["Instrument", "TR.CUSIP"]  # Use "Instrument" instead of "TR.PrimaryInstrument"
)

if err:
    print("Error:", err)
else:
    # Print out the columns to verify
    print("Columns in universe_df:", universe_df.columns)
    print(universe_df.head())

    # If "Instrument" is indeed present, do:
    ric_list = universe_df["Instrument"].dropna().unique().tolist()
    print("Found instruments:", len(ric_list))
# Out:
# Error: [{'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'ECL.N'", 'row': 0}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'STZ.N'", 'row': 1}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'EA.OQ'", 'row': 2}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'DHIL.OQ'", 'row': 3}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'EMR.N'", 'row': 4}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'EBF.N'", 'row': 5}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'EOG.N'", 'row': 6}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'GNSS.OQ'", 'row': 7}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'ENZ.N'", 'row': 8}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'OSUR.OQ'", 'row': 9}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'EFX.N'", 'row': 10}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'EQT.N'", 'row': 11}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'ESCA.OQ'", 'row': 12}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'NEU.N'", 'row': 13}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'EXPD.N'", 'row': 14}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'BOOM.OQ'", 'row': 15}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'XOM.N'", 'row': 16}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'EZPW.OQ'", 'row': 17}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'FMC.N'", 'row': 18}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'NEE.N'", 'row': 19}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'ADM.N'", 'row': 20}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'VZ.N'", 'row': 21}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'FRPH.OQ'", 'row': 22}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'OPY.N'", 'row': 23}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'EXPO.OQ'", 'row': 24}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'FICO.N'", 'row': 25}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'FARM.OQ'", 'row': 26}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'FAST.OQ'", 'row': 27}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT' was not found in response for the instrument 'FDX.N'", 'row': 28}, {'code': 251658244, 'col': 1, 'message': "Error: Field 'INSTRUMENT ...

# %%
# Example chunked retrieval from 2012 to present, monthly frequency
FIELDS = [
    "TR.ClosePrice",
    "TR.MarketCap",
    "TR.Volume",
    "TR.TRESGScore",
    "TR.EnvironmentPillarScore",
    "TR.SocialPillarScore",
    "TR.CorporateGovernancePillarScore"
]
PARAMETERS = {
    "SDate": "2012-01-01",
    "EDate": "2023-12-31",
    "FRQ": "M"  # monthly
}

# chunker function:
def chunker(seq, size):
    for pos in range(0, len(seq), size):
        yield seq[pos:pos + size]

all_frames = []
for subset in chunker(ric_list, 200):
    df_chunk, err_chunk = ek.get_data(subset, fields=FIELDS, parameters=PARAMETERS)
    if err_chunk:
        print("Error in chunk:", err_chunk)
        continue
    all_frames.append(df_chunk)

combined_df = pd.concat(all_frames, ignore_index=True)
print(combined_df.head(50))
print("Total records:", len(combined_df))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 24
#      22 all_frames = []
#      23 for subset in chunker(ric_list, 200):
# ---> 24     df_chunk, err_chunk = ek.get_data(subset, fields=FIELDS, parameters=PARAMETERS)
#      25     if err_chunk:
#      26         print("Error in chunk:", err_chunk)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\eikon\data_grid.py:190, in get_data(instruments, fields, parameters, field_name, raw_output, debug)
#     187 if _endpoint == DataGridAsync_UDF_endpoint:
#     188     payload = {'requests': [payload]}
# --> 190 result = eikon.json_requests.send_json_request(_endpoint, payload, debug=debug)
#     192 if result.get('responses'):
#     193     result = result['responses'][0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\eikon\json_requests.py:107, in send_json_request(entity, payload, debug)
#     105 # Manage specifically DataGrid async mode
#     106 if entity.startswith('DataGrid') and entity.endswith('Async'):
# --> 107     ticket = _check_ticket_async(result)
#     108     while ticket:
#     109         ticket_request = {'Entity': {
#     110                              'E': entity,
#     111                              'W': {'requests': [{'ticket': ticket}]}
#     112                          }}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\eikon\json_requests.py:175, in _check_ticket_async(server_response)
#     173                 message = message + 's'
#     174             logger.info(message)
# --> 175             time.sleep(ticket_duration / 1000.0)
#     176             return ticket_value
#     177 return None
#
# KeyboardInterrupt:

# %%
import eikon as ek
import pandas as pd

ek.set_app_key("5d67b807cafe47c0acf2248d6f56ec409013c511")

# %%
# 1) Screener expression with multiple countries
#    We filter by exchange country codes (TR.ExchangeCountryCode).
#    Also, TR.TRESGScore(Period=FY0) > 0 to ensure we only get companies with an ESG score.
screener_expr = """
SCREEN(
  U(IN(Equity(active,public,primary))/*UNV:Public*/),
  IN(TR.ExchangeCountryCode,"US","GB","JP","DE","FR","CA","AU","CN"),
  TR.TRESGScore(Period=FY0) > 0
)
"""

# 2) We request at least the RIC and a couple of quick reference fields (e.g., TR.CommonName, ESG Score).
fields_for_universe = [
    "TR.RIC",
    "TR.CommonName",
    "TR.TRESGScore"  # just to confirm coverage in the screener result
]

# 3) Retrieve the universe
df_universe, err = ek.get_data(screener_expr, fields_for_universe)

if err:
    raise RuntimeError(f"Screener error: {err}")

print("Columns returned:", df_universe.columns)
print("First 10 rows:\n", df_universe.head(10))
print("Total instruments found:", len(df_universe))

# 4) Extract RICs
ric_col = "RIC" if "RIC" in df_universe.columns else "Instrument"
ric_list = df_universe[ric_col].dropna().unique().tolist()

print("Number of unique RICs in the universe:", len(ric_list))
# Out:
# Columns returned: Index(['Instrument', 'RIC', 'Company Common Name', 'ESG Score'], dtype='object')
# First 10 rows:
#    Instrument      RIC             Company Common Name  ESG Score
# 0      KE.OQ    KE.OQ         Kimball Electronics Inc  60.279457
# 1       TX.N     TX.N                      Ternium SA  51.219531
# 2    MELI.OQ  MELI.OQ                MercadoLibre Inc  54.954479
# 3     CBA.AX   CBA.AX  Commonwealth Bank of Australia   89.05102
# 4     BKW.AX   BKW.AX                  Brickworks Ltd  54.386808
# 5     BOQ.AX   BOQ.AX          Bank of Queensland Ltd  69.802774
# 6     AOV.AX   AOV.AX                      Amotiv Ltd   30.17005
# 7     HVN.AX   HVN.AX      Harvey Norman Holdings Ltd  21.047588
# 8     MAH.AX   MAH.AX           Macmahon Holdings Ltd  40.662416
# 9     PMV.AX   PMV.AX         Premier Investments Ltd  41.575733
# Total instruments found: 7235
# Number of unique RICs in the universe: 7235

# %%
print(df_universe.head())
# Out:
#   Instrument      RIC             Company Common Name  ESG Score
# 0      KE.OQ    KE.OQ         Kimball Electronics Inc  60.279457
# 1       TX.N     TX.N                      Ternium SA  51.219531
# 2    MELI.OQ  MELI.OQ                MercadoLibre Inc  54.954479
# 3     CBA.AX   CBA.AX  Commonwealth Bank of Australia   89.05102
# 4     BKW.AX   BKW.AX                  Brickworks Ltd  54.386808

# %%
# Chunking function
def chunker(seq, size):
    for pos in range(0, len(seq), size):
        yield seq[pos:pos + size]

CHUNK_SIZE = 200

FIELDS = [
    "TR.CommonName",
    "TR.HeadquartersCountry",
    "TR.TRBCIndustry",
    "TR.MarketCap",
    "TR.Volume",
    "TR.ClosePrice",
    "TR.TRESGScore",
    "TR.EnvironmentPillarScore",
    "TR.SocialPillarScore",
    "TR.CorporateGovernancePillarScore",
    "TR.CO2Emissions"
]

PARAMS = {
    "SDate": "2012-01-01",
    "EDate": "2023-12-31",
    "FRQ": "M"
}

ric_list = df_universe["RIC"].tolist()

all_dfs = []
for i, subset in enumerate(chunker(ric_list, CHUNK_SIZE)):
    print(f"Processing chunk {i+1} with {len(subset)} RICs...")

    df_chunk, err_chunk = ek.get_data(
        instruments=subset,
        fields=FIELDS,
        parameters=PARAMS
    )

    if err_chunk:
        print(f"Error in chunk {i+1}:", err_chunk)
        continue

    all_dfs.append(df_chunk)

# Combine all chunks into one DataFrame
if all_dfs:
    combined_df = pd.concat(all_dfs, ignore_index=True)
else:
    combined_df = pd.DataFrame()

# Rename for consistency with df_universe
combined_df.rename(columns={
    "Instrument": "RIC",
    "Common Name": "Company Common Name",
    "ESG Score": "ESG Score (Retrieved)"
}, inplace=True)

# Merge historical time series with static company info
df_final = pd.merge(
    combined_df,
    df_universe,
    on="RIC",
    how="left",
    suffixes=('', '_Original')
)

# Optional: drop or rearrange columns as needed
df_final = df_final[[
    'RIC', 'Company Common Name', 'ESG Score',
    'Date', 'Close Price', 'Volume', 'Market Cap',
    'Headquarters Country', 'Industry',
    'ESG Score (Retrieved)', 'Environmental Pillar Score',
    'Social Pillar Score', 'Corporate Governance Pillar Score',
    'CO2 Emissions'
]]

print(df_final.head())
# Out:
# Processing chunk 1 with 200 RICs...
# Processing chunk 2 with 200 RICs...
# Error in chunk 2: [{'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 288}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 288}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 289}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 289}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 290}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 290}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 291}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 291}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 292}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 292}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 293}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 293}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 294}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 294}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 295}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 295}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 296}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 296}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 297}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 297}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 298}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 298}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 299}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 299}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 300}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 300}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 301}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 301}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 302}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the f ...
# Processing chunk 3 with 200 RICs...
# C:\Users\jr24440\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\cast.py:1056: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# C:\Users\jr24440\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\cast.py:1080: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# Processing chunk 4 with 200 RICs...
# Processing chunk 5 with 200 RICs...
# Processing chunk 6 with 200 RICs...
# Error in chunk 6: [{'code': 100, 'col': 1, 'message': 'Asynchronous Query library internal error.', 'row': 0}, {'code': 100, 'col': 2, 'message': 'Asynchronous Query library internal error.', 'row': 0}, {'code': 100, 'col': 3, 'message': 'Asynchronous Query library internal error.', 'row': 0}, {'code': 100, 'col': 4, 'message': 'Asynchronous Query library internal error.', 'row': 0}, {'code': 100, 'col': 5, 'message': 'Asynchronous Query library internal error.', 'row': 0}, {'code': 100, 'col': 6, 'message': 'Asynchronous Query library internal error.', 'row': 0}, {'code': 100, 'col': 7, 'message': 'Asynchronous Query library internal error.', 'row': 0}, {'code': 100, 'col': 8, 'message': 'Asynchronous Query library internal error.', 'row': 0}, {'code': 100, 'col': 9, 'message': 'Asynchronous Query library internal error.', 'row': 0}, {'code': 100, 'col': 10, 'message': 'Asynchronous Query library internal error.', 'row': 0}, {'code': 100, 'col': 11, 'message': 'Asynchronous Query library internal error.', 'row': 0}, {'code': 100, 'col': 1, 'message': 'Asynchronous Query library internal error.', 'row': 1}, {'code': 100, 'col': 2, 'message': 'Asynchronous Query library internal error.', 'row': 1}, {'code': 100, 'col': 3, 'message': 'Asynchronous Query library internal error.', 'row': 1}, {'code': 100, 'col': 4, 'message': 'Asynchronous Query library internal error.', 'row': 1}, {'code': 100, 'col': 5, 'message': 'Asynchronous Query library internal error.', 'row': 1}, {'code': 100, 'col': 6, 'message': 'Asynchronous Query library internal error.', 'row': 1}, {'code': 100, 'col': 7, 'message': 'Asynchronous Query library internal error.', 'row': 1}, {'code': 100, 'col': 8, 'message': 'Asynchronous Query library internal error.', 'row': 1}, {'code': 100, 'col': 9, 'message': 'Asynchronous Query library internal error.', 'row': 1}, {'code': 100, 'col': 10, 'message': 'Asynchronous Query library internal error.', 'row': 1}, {'code': 100, 'col': 11, 'message': 'Asynchronous Query library internal error.', 'row': 1}, {'code': 100, 'col': 1, 'message': 'Asynchronous Query library internal error.', 'row': 2}, {'code': 100, 'col': 2, 'message': 'Asynchronous Query library internal error.', 'row': 2}, {'code': 100, 'col': 3, 'message': 'Asynchronous Query library internal error.', 'row': 2}, {'code': 100, 'col': 4, 'message': 'Asynchronous Query library internal error.', 'row': 2}, {'code': 100, 'col': 5, 'message': 'Asynchronous Query library internal error.', 'row': 2}, {'code': 100, 'col': 6, 'message': 'Asynchronous Query library internal error.', 'row': 2}, {'code': 100, 'col': 7, 'message': 'Asynchronous Query library internal error.', 'row': 2}, {'code': 100, 'col': 8, 'message': 'Asynchronous Query library internal error.', 'row': 2}, {'code': 100, 'col': 9, 'message': 'Asynchronous Query library internal error.', 'row': 2}, {'code': 100, 'col': 10, 'message': 'Asynchronous Query library internal error.', 'row': 2}, {'code': 100, 'col': 11, 'message': 'Asynchronous Query library internal error.', 'row': 2}, {'code': 100, 'col': 1, 'message': 'Asynchronous Query library internal error.', 'row': 3}, {'code': 100, 'col': 2, 'message': 'Asynchronous Query library internal error.', 'row': 3}, {'code': 100, 'col': 3, 'message': 'Asynchronous Query library internal error.', 'row': 3}, {'code': 100, 'col': 4, 'message': 'Asynchronous Query library internal error.', 'row': 3}, {'code': 100, 'col': 5, 'message': 'Asynchronous Query library internal error.', 'row': 3}, {'code': 100, 'col': 6, 'message': 'Asynchronous Query library internal error.', 'row': 3}, {'code': 100, 'col': 7, 'message': 'Asynchronous Query library internal error.', 'row': 3}, {'code': 100, 'col': 8, 'message': 'Asynchronous Query library internal error.', 'row': 3}, {'code': 100, 'col': 9, 'message': 'Asynchronous Query library internal error.', 'row': 3}, {'code': 100, 'col': 10, 'message': 'Asynchronous Query library internal error.', 'row': 3}, {'code': 100, 'col ...
# Processing chunk 7 with 200 RICs...
# Processing chunk 8 with 200 RICs...
# Processing chunk 9 with 200 RICs...
# Processing chunk 10 with 200 RICs...
# Processing chunk 11 with 200 RICs...
# Processing chunk 12 with 200 RICs...
# Processing chunk 13 with 200 RICs...
# Processing chunk 14 with 200 RICs...
# Processing chunk 15 with 200 RICs...
# Processing chunk 16 with 200 RICs...
# Processing chunk 17 with 200 RICs...
# Processing chunk 18 with 200 RICs...
# Processing chunk 19 with 200 RICs...
# Processing chunk 20 with 200 RICs...
# Processing chunk 21 with 200 RICs...
# Processing chunk 22 with 200 RICs...
# Processing chunk 23 with 200 RICs...
# Processing chunk 24 with 200 RICs...
# Processing chunk 25 with 200 RICs...
# Processing chunk 26 with 200 RICs...
# Processing chunk 27 with 200 RICs...
# Processing chunk 28 with 200 RICs...
# Processing chunk 29 with 200 RICs...
# Processing chunk 30 with 200 RICs...
# Processing chunk 31 with 200 RICs...
# Processing chunk 32 with 200 RICs...
# Processing chunk 33 with 200 RICs...
# Processing chunk 34 with 200 RICs...
# Processing chunk 35 with 200 RICs...
# Processing chunk 36 with 200 RICs...
# Error in chunk 36: [{'code': 413, 'col': 4, 'message': 'Unable to resolve some identifier(s).', 'row': 9216}, {'code': 413, 'col': 6, 'message': 'Unable to resolve some identifier(s).', 'row': 9216}, {'code': 413, 'col': 7, 'message': 'Unable to resolve some identifier(s).', 'row': 9216}, {'code': 413, 'col': 8, 'message': 'Unable to resolve some identifier(s).', 'row': 9216}, {'code': 413, 'col': 1, 'message': 'Unable to resolve some identifier(s).', 'row': 9217}, {'code': 413, 'col': 2, 'message': 'Unable to resolve some identifier(s).', 'row': 9217}, {'code': 413, 'col': 3, 'message': 'Unable to resolve some identifier(s).', 'row': 9217}, {'code': 413, 'col': 4, 'message': 'Unable to resolve some identifier(s).', 'row': 9217}, {'code': 413, 'col': 6, 'message': 'Unable to resolve some identifier(s).', 'row': 9217}, {'code': 413, 'col': 7, 'message': 'Unable to resolve some identifier(s).', 'row': 9217}, {'code': 413, 'col': 8, 'message': 'Unable to resolve some identifier(s).', 'row': 9217}, {'code': 413, 'col': 1, 'message': 'Unable to resolve some identifier(s).', 'row': 9218}, {'code': 413, 'col': 2, 'message': 'Unable to resolve some identifier(s).', 'row': 9218}, {'code': 413, 'col': 3, 'message': 'Unable to resolve some identifier(s).', 'row': 9218}, {'code': 413, 'col': 4, 'message': 'Unable to resolve some identifier(s).', 'row': 9218}, {'code': 413, 'col': 6, 'message': 'Unable to resolve some identifier(s).', 'row': 9218}, {'code': 413, 'col': 7, 'message': 'Unable to resolve some identifier(s).', 'row': 9218}, {'code': 413, 'col': 8, 'message': 'Unable to resolve some identifier(s).', 'row': 9218}, {'code': 413, 'col': 1, 'message': 'Unable to resolve some identifier(s).', 'row': 9219}, {'code': 413, 'col': 2, 'message': 'Unable to resolve some identifier(s).', 'row': 9219}, {'code': 413, 'col': 3, 'message': 'Unable to resolve some identifier(s).', 'row': 9219}, {'code': 413, 'col': 4, 'message': 'Unable to resolve some identifier(s).', 'row': 9219}, {'code': 413, 'col': 6, 'message': 'Unable to resolve some identifier(s).', 'row': 9219}, {'code': 413, 'col': 7, 'message': 'Unable to resolve some identifier(s).', 'row': 9219}, {'code': 413, 'col': 8, 'message': 'Unable to resolve some identifier(s).', 'row': 9219}, {'code': 413, 'col': 1, 'message': 'Unable to resolve some identifier(s).', 'row': 9220}, {'code': 413, 'col': 2, 'message': 'Unable to resolve some identifier(s).', 'row': 9220}, {'code': 413, 'col': 3, 'message': 'Unable to resolve some identifier(s).', 'row': 9220}, {'code': 413, 'col': 4, 'message': 'Unable to resolve some identifier(s).', 'row': 9220}, {'code': 413, 'col': 6, 'message': 'Unable to resolve some identifier(s).', 'row': 9220}, {'code': 413, 'col': 7, 'message': 'Unable to resolve some identifier(s).', 'row': 9220}, {'code': 413, 'col': 8, 'message': 'Unable to resolve some identifier(s).', 'row': 9220}, {'code': 413, 'col': 1, 'message': 'Unable to resolve some identifier(s).', 'row': 9221}, {'code': 413, 'col': 2, 'message': 'Unable to resolve some identifier(s).', 'row': 9221}, {'code': 413, 'col': 3, 'message': 'Unable to resolve some identifier(s).', 'row': 9221}, {'code': 413, 'col': 4, 'message': 'Unable to resolve some identifier(s).', 'row': 9221}, {'code': 413, 'col': 6, 'message': 'Unable to resolve some identifier(s).', 'row': 9221}, {'code': 413, 'col': 7, 'message': 'Unable to resolve some identifier(s).', 'row': 9221}, {'code': 413, 'col': 8, 'message': 'Unable to resolve some identifier(s).', 'row': 9221}, {'code': 413, 'col': 1, 'message': 'Unable to resolve some identifier(s).', 'row': 9222}, {'code': 413, 'col': 2, 'message': 'Unable to resolve some identifier(s).', 'row': 9222}, {'code': 413, 'col': 3, 'message': 'Unable to resolve some identifier(s).', 'row': 9222}, {'code': 413, 'col': 4, 'message': 'Unable to resolve some identifier(s).', 'row': 9222}, {'code': 413, 'col': 6, 'message': 'Unable to resolve some identifier(s).', 'row': 9222}, {'code': 413, 'col': ...
# Processing chunk 37 with 35 RICs...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 69
#      60 df_final = pd.merge(
#      61     combined_df,
#      62     df_universe,
#    (...)
#      65     suffixes=('', '_Original')
#      66 )
#      68 # Optional: drop or rearrange columns as needed
# ---> 69 df_final = df_final[[
#      70     'RIC', 'Company Common Name', 'ESG Score',
#      71     'Date', 'Close Price', 'Volume', 'Market Cap',
#      72     'Headquarters Country', 'Industry',
#      73     'ESG Score (Retrieved)', 'Environmental Pillar Score',
#      74     'Social Pillar Score', 'Corporate Governance Pillar Score',
#      75     'CO2 Emissions'
#      76 ]]
#      78 print(df_final.head())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Date', 'Market Cap', 'Headquarters Country', 'Industry', 'Corporate Governance Pillar Score', 'CO2 Emissions'] not in index"

# %%
import eikon as ek
import pandas as pd

def chunker(seq, size):
    for pos in range(0, len(seq), size):
        yield seq[pos:pos + size]

CHUNK_SIZE = 100  # Conservative chunk size to avoid timeouts

FIELDS = [
    "TR.CommonName",
    "TR.HeadquartersCountry",
    "TR.TRBCIndustry",
    "TR.MarketCap",
    "TR.Volume",
    "TR.ClosePrice",
    "TR.TRESGScore",
    "TR.EnvironmentPillarScore",
    "TR.SocialPillarScore",
    "TR.CorporateGovernancePillarScore",
    "TR.CO2Emissions"
]

PARAMS = {
    "SDate": "2012-01-01",
    "EDate": "2023-12-31",
    "FRQ": "M"  # Monthly
}

ric_list = df_universe["RIC"].tolist()

all_dfs = []
for i, subset in enumerate(chunker(ric_list, CHUNK_SIZE)):
    print(f"Processing chunk {i+1} with {len(subset)} RICs...")

    df_chunk, err = ek.get_data(
        instruments=subset,
        fields=FIELDS,
        parameters=PARAMS
    )

    if err:
        print(f"Error in chunk {i+1}:", err)
        continue

    all_dfs.append(df_chunk)

# Combine everything
df_combined = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()

# Rename columns for consistency
df_combined.rename(columns={
    "Instrument": "RIC",
    "Date": "Date",
    "TR.CommonName": "Company Common Name",
    "TR.HeadquartersCountry": "Headquarters Country",
    "TR.TRBCIndustry": "Industry",
    "TR.MarketCap": "Market Cap",
    "TR.Volume": "Volume",
    "TR.ClosePrice": "Close Price",
    "TR.TRESGScore": "ESG Score (Retrieved)",
    "TR.EnvironmentPillarScore": "Environmental Pillar Score",
    "TR.SocialPillarScore": "Social Pillar Score",
    "TR.CorporateGovernancePillarScore": "Corporate Governance Pillar Score",
    "TR.CO2Emissions": "CO2 Emissions"
}, inplace=True)

# Merge with original ESG Score from your static df_universe
df_final = pd.merge(df_combined, df_universe[['RIC', 'ESG Score']], on="RIC", how="left")

# Order columns neatly
columns_order = [
    'RIC', 'Company Common Name', 'ESG Score', 'Date',
    'Close Price', 'Volume', 'Market Cap',
    'Headquarters Country', 'Industry',
    'ESG Score (Retrieved)', 'Environmental Pillar Score',
    'Social Pillar Score', 'Corporate Governance Pillar Score',
    'CO2 Emissions'
]

# Keep only existing columns to avoid KeyError
df_final = df_final[[col for col in columns_order if col in df_final.columns]]

print("\n✅ Final time-series DataFrame:")
print(df_final.head())
# Out:
# Processing chunk 1 with 100 RICs...
# Processing chunk 2 with 100 RICs...
# Processing chunk 3 with 100 RICs...
# Error in chunk 3: [{'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 288}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 288}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 289}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 289}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 290}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 290}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 291}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 291}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 292}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 292}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 293}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 293}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 294}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 294}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 295}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 295}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 296}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 296}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 297}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 297}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 298}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 298}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 299}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 299}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 300}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 300}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 301}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 301}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 302}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the f ...
# Processing chunk 4 with 100 RICs...
# Error in chunk 4: [{'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12960}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12960}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12961}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12961}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12962}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12962}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12963}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12963}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12964}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12964}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12965}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12965}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12966}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12966}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12967}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12967}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12968}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12968}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12969}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12969}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12970}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12970}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12971}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12971}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12972}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12972}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12973}, {'code': 416, 'col': 5, 'message': "Unable to collect data for the field 'TR.CLOSEPRICE' and some specific identifier(s).", 'row': 12973}, {'code': 416, 'col': 4, 'message': "Unable to collect data for the field 'TR.Volume' and some specific identifier(s).", 'row': 12974}, {'code': 4 ...
# Processing chunk 5 with 100 RICs...
# C:\Users\jr24440\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\cast.py:1056: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# C:\Users\jr24440\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\cast.py:1080: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# Processing chunk 6 with 100 RICs...
# Processing chunk 7 with 100 RICs...
# Processing chunk 8 with 100 RICs...
# Processing chunk 9 with 100 RICs...
# Processing chunk 10 with 100 RICs...
# Processing chunk 11 with 100 RICs...
# Processing chunk 12 with 100 RICs...
# Processing chunk 13 with 100 RICs...
# Processing chunk 14 with 100 RICs...
# Processing chunk 15 with 100 RICs...
# Processing chunk 16 with 100 RICs...
# Processing chunk 17 with 100 RICs...
# Processing chunk 18 with 100 RICs...
# Processing chunk 19 with 100 RICs...
# Processing chunk 20 with 100 RICs...
# Processing chunk 21 with 100 RICs...
# Processing chunk 22 with 100 RICs...
# Processing chunk 23 with 100 RICs...
# Processing chunk 24 with 100 RICs...
# Processing chunk 25 with 100 RICs...
# Processing chunk 26 with 100 RICs...
# Processing chunk 27 with 100 RICs...
# Processing chunk 28 with 100 RICs...
# Processing chunk 29 with 100 RICs...
# Processing chunk 30 with 100 RICs...
# Processing chunk 31 with 100 RICs...
# Processing chunk 32 with 100 RICs...
# Processing chunk 33 with 100 RICs...
# Processing chunk 34 with 100 RICs...
# Processing chunk 35 with 100 RICs...
# Processing chunk 36 with 100 RICs...
# Processing chunk 37 with 100 RICs...
# Processing chunk 38 with 100 RICs...
# Processing chunk 39 with 100 RICs...
# Processing chunk 40 with 100 RICs...
# Processing chunk 41 with 100 RICs...
# Processing chunk 42 with 100 RICs...
# Processing chunk 43 with 100 RICs...
# Processing chunk 44 with 100 RICs...
# Processing chunk 45 with 100 RICs...
# Processing chunk 46 with 100 RICs...
# Processing chunk 47 with 100 RICs...
# Processing chunk 48 with 100 RICs...
# Processing chunk 49 with 100 RICs...
# Processing chunk 50 with 100 RICs...
# Processing chunk 51 with 100 RICs...
# Processing chunk 52 with 100 RICs...
# Processing chunk 53 with 100 RICs...
# Processing chunk 54 with 100 RICs...
# Processing chunk 55 with 100 RICs...
# Processing chunk 56 with 100 RICs...
# Processing chunk 57 with 100 RICs...
# Processing chunk 58 with 100 RICs...
# Processing chunk 59 with 100 RICs...
# Processing chunk 60 with 100 RICs...
# Processing chunk 61 with 100 RICs...
# Processing chunk 62 with 100 RICs...
# Processing chunk 63 with 100 RICs...
# Processing chunk 64 with 100 RICs...
# Processing chunk 65 with 100 RICs...
# Processing chunk 66 with 100 RICs...
# Processing chunk 67 with 100 RICs...
# Processing chunk 68 with 100 RICs...
# Processing chunk 69 with 100 RICs...
# Processing chunk 70 with 100 RICs...
# Processing chunk 71 with 100 RICs...
# Processing chunk 72 with 100 RICs...
# Processing chunk 73 with 35 RICs...
#
# ✅ Final time-series DataFrame:
#      RIC      Company Common Name  Close Price  Volume  \
# 0  KE.OQ  Kimball Electronics Inc         11.0     0.0
# 1  KE.OQ                                 12.02     0.0
# 2  KE.OQ                                 10.18     0.0
# 3  KE.OQ                                 12.52     0.0
# 4  KE.OQ                                 14.14     0.0
#
#    Environmental Pillar Score  Social Pillar Score
# 0                        <NA>                 <NA>
# 1                        <NA>                 <NA>
# 2                        <NA>                 <NA>
# 3                        <NA>                 <NA>
# 4                        <NA>                 <NA>

# %%
print(df_final.head())
# Out:
#      RIC      Company Common Name  Close Price  Volume  \
# 0  KE.OQ  Kimball Electronics Inc         11.0     0.0
# 1  KE.OQ                                 12.02     0.0
# 2  KE.OQ                                 10.18     0.0
# 3  KE.OQ                                 12.52     0.0
# 4  KE.OQ                                 14.14     0.0
#
#    Environmental Pillar Score  Social Pillar Score
# 0                        <NA>                 <NA>
# 1                        <NA>                 <NA>
# 2                        <NA>                 <NA>
# 3                        <NA>                 <NA>
# 4                        <NA>                 <NA>

# %%
if all_dfs:
    combined_df = pd.concat(all_dfs, ignore_index=True)
    print("Columns returned by Eikon:", combined_df.columns.tolist())
else:
    combined_df = pd.DataFrame()
    print("No data retrieved.")
# Out:
# Columns returned by Eikon: ['Instrument', 'Company Common Name', 'Country of Headquarters', 'TRBC Industry Name', 'Volume', 'Close Price', 'ESG Score', 'Environmental Pillar Score', 'Social Pillar Score']

# %%
print(df_final.head())
# Out:
#      RIC      Company Common Name  Close Price  Volume  \
# 0  KE.OQ  Kimball Electronics Inc         11.0     0.0
# 1  KE.OQ                                 12.02     0.0
# 2  KE.OQ                                 10.18     0.0
# 3  KE.OQ                                 12.52     0.0
# 4  KE.OQ                                 14.14     0.0
#
#    Environmental Pillar Score  Social Pillar Score
# 0                        <NA>                 <NA>
# 1                        <NA>                 <NA>
# 2                        <NA>                 <NA>
# 3                        <NA>                 <NA>
# 4                        <NA>                 <NA>

# %%
combined_df = combined_df.dropna()

# %%
print(combined_df.head())
# Out:
#   Instrument      Company Common Name   Country of Headquarters  \
# 0      KE.OQ  Kimball Electronics Inc  United States of America
# 1      KE.OQ
# 2      KE.OQ
# 3      KE.OQ
# 4      KE.OQ
#
#   TRBC Industry Name  Volume  Close Price  ESG Score  \
# 0     Semiconductors     0.0         11.0       <NA>
# 1                        0.0        12.02       <NA>
# 2                        0.0        10.18       <NA>
# 3                        0.0        12.52       <NA>
# 4                        0.0        14.14       <NA>
#
#    Environmental Pillar Score  Social Pillar Score
# 0                        <NA>                 <NA>
# 1                        <NA>                 <NA>
# 2                        <NA>                 <NA>
# 3                        <NA>                 <NA>
# 4                        <NA>                 <NA>

# %%
print("Columns:", combined_df.columns)
# Out:
# Columns: Index(['Instrument', 'Company Common Name', 'Country of Headquarters',
#        'Close Price', 'Volume', 'TRBC Industry Name', 'ESG Score',
#        'Environmental Pillar Score', 'Social Pillar Score'],
#       dtype='object')

# %%
import pandas as pd

# Assume combined_df is already loaded

# Step 1: Create per-instrument monthly dates
def generate_monthly_dates(group):
    group = group.copy()
    group['Date'] = pd.date_range(start='2012-01-01', periods=len(group), freq='MS')
    return group

combined_df = combined_df.groupby('Instrument', group_keys=False).apply(generate_monthly_dates)

# Step 2: Clean + fill metadata
fields_to_fill = ['Company Common Name', 'Country of Headquarters', 'TRBC Industry Name']

# Replace empty strings with NA so ffill works
combined_df[fields_to_fill] = combined_df[fields_to_fill].replace('', pd.NA)

# Forward-fill within each instrument group
combined_df[fields_to_fill] = combined_df.groupby('Instrument')[fields_to_fill].ffill()

# ✅ Optional: Reorder for readability
combined_df = combined_df[['Date', 'Instrument'] + fields_to_fill +
                          [col for col in combined_df.columns if col not in ['Date', 'Instrument'] + fields_to_fill]]

# Preview the fix
print(combined_df.head(10))
# Out:
# C:\Users\jr24440\AppData\Local\Temp\ipykernel_35236\1061285194.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   combined_df = combined_df.groupby('Instrument', group_keys=False).apply(generate_monthly_dates)
#         Date Instrument      Company Common Name   Country of Headquarters  \
# 0 2012-01-01      KE.OQ  Kimball Electronics Inc  United States of America
# 1 2012-02-01      KE.OQ  Kimball Electronics Inc  United States of America
# 2 2012-03-01      KE.OQ  Kimball Electronics Inc  United States of America
# 3 2012-04-01      KE.OQ  Kimball Electronics Inc  United States of America
# 4 2012-05-01      KE.OQ  Kimball Electronics Inc  United States of America
# 5 2012-06-01      KE.OQ  Kimball Electronics Inc  United States of America
# 6 2012-07-01      KE.OQ  Kimball Electronics Inc  United States of America
# 7 2012-08-01      KE.OQ  Kimball Electronics Inc  United States of America
# 8 2012-09-01      KE.OQ  Kimball Electronics Inc  United States of America
# 9 2012-10-01      KE.OQ  Kimball Electronics Inc  United States of America
#
#   TRBC Industry Name  Volume  Close Price  ESG Score  \
# 0     Semiconductors     0.0         11.0       <NA>
# 1     Semiconductors     0.0        12.02       <NA>
# 2     Semiconductors     0.0        10.18       <NA>
# 3     Semiconductors     0.0        12.52       <NA>
# 4     Semiconductors     0.0        14.14       <NA>
# 5     Semiconductors     0.0        12.79       <NA>
# 6     Semiconductors     0.0        15.58       <NA>
# 7     Semiconductors     0.0        14.59       <NA>
# 8     Semiconductors     0.0        13.41       <NA>
# 9     Semiconductors     0.0        11.75       <NA>
#
#    Environmental Pillar Score  Social Pillar Score
# 0                        <NA>                 <NA>
# 1                        <NA>                 <NA>
# 2                        <NA>                 <NA>
# 3                        <NA>                 <NA>
# 4                        <NA>                 <NA>
# 5                        <NA>                 <NA>
# 6                        <NA>                 <NA>
# 7                        <NA>                 <NA>
# 8                        <NA>                 <NA>
# 9                        <NA>                 <NA>

# %%
print(combined_df.describe())
# Out:
#                                 Date           Volume       Close Price  \
# count                        1012754        1006034.0          811757.0
# mean   2017-12-15 22:53:48.729582592   3193775.540225    1941327.561812
# min              2012-01-01 00:00:00              0.0          0.000001
# 25%              2014-12-01 00:00:00              0.0             10.17
# 50%              2017-12-01 00:00:00           7627.5             27.89
# 75%              2020-12-01 00:00:00         410717.5              97.3
# max              2023-12-01 00:00:00     8826611382.0     84510000000.0
# std                              NaN  25184735.865534  288183827.708544
#
#        ESG Score  Environmental Pillar Score  Social Pillar Score
# count   528875.0                    528863.0             528863.0
# mean   42.032416                   34.309896            42.630863
# min     0.073196                         0.0             0.167672
# 25%    25.350696                    7.527453             24.49729
# 50%    39.437347                   28.630316            39.852417
# 75%    57.725914                   57.948932            59.646135
# max    95.897296                   98.718593             98.63592
# std     20.64526                   28.548785            23.031892

# %%
# Number of unique companies
num_companies = combined_df['Company Common Name'].nunique()

# Full list of unique industries
unique_industries = combined_df['TRBC Industry Name'].dropna().unique()
num_industries = len(unique_industries)

print(f"✅ Number of unique companies: {num_companies}")
print(f"✅ Number of unique industries: {num_industries}")
print("\n🧾 Full list of industries:")
for industry in sorted(unique_industries):
    print("-", industry)
# Out:
# ✅ Number of unique companies: 7034
# ✅ Number of unique industries: 140
#
# 🧾 Full list of industries:
# - Advanced Medical Equipment & Technology
# - Advertising & Marketing
# - Aerospace & Defense
# - Agricultural Chemicals
# - Airlines
# - Airport Operators & Services
# - Aluminum
# - Apparel & Accessories
# - Apparel & Accessories Retailers
# - Appliances, Tools & Housewares
# - Auto & Truck Manufacturers
# - Auto Vehicles, Parts & Service Retailers
# - Auto, Truck & Motorcycle Parts
# - Banks
# - Biotechnology & Medical Research
# - Blockchain & Cryptocurrency
# - Brewers
# - Broadcasting
# - Business Support Services
# - Business Support Supplies
# - Casinos & Gaming
# - Closed End Funds
# - Coal
# - Commercial Printing Services
# - Commercial REITs
# - Commodity Chemicals
# - Communications & Networking
# - Computer & Electronics Retailers
# - Computer Hardware
# - Construction & Engineering
# - Construction Materials
# - Construction Supplies & Fixtures
# - Consumer Goods Conglomerates
# - Consumer Lending
# - Consumer Publishing
# - Corporate Financial Services
# - Courier, Postal, Air Freight & Land-based Logistics
# - Department Stores
# - Discount Stores
# - Distillers & Wineries
# - Diversified Chemicals
# - Diversified Industrial Goods Wholesale
# - Diversified Investment Services
# - Diversified Mining
# - Diversified REITs
# - Drug Retailers
# - Electric Utilities
# - Electrical Components & Equipment
# - Electronic Equipment & Parts
# - Employment Services
# - Entertainment Production
# - Environmental Services & Equipment
# - Financial & Commodity Market Operators & Service Providers
# - Financial Technology (Fintech)
# - Fishing & Farming
# - Food Processing
# - Food Retail & Distribution
# - Footwear
# - Forest & Wood Products
# - Gold
# - Ground Freight & Logistics
# - Healthcare Facilities & Services
# - Heavy Electrical Equipment
# - Heavy Machinery & Vehicles
# - Highways & Rail Tracks
# - Home Furnishings
# - Home Furnishings Retailers
# - Home Improvement Products & Services Retailers
# - Homebuilding
# - Hotels, Motels & Cruise Lines
# - Household Electronics
# - Household Products
# - IT Services & Consulting
# - Independent Power Producers
# - Industrial Machinery & Equipment
# - Integrated Hardware & Software
# - Integrated Oil & Gas
# - Integrated Telecommunications Services
# - Investment Banking & Brokerage Services
# - Investment Holding Companies
# - Investment Management & Fund Operators
# - Iron & Steel
# - Leisure & Recreation
# - Life & Health Insurance
# - Managed Healthcare
# - Marine Freight & Logistics
# - Marine Port Services
# - Medical Equipment, Supplies & Distribution
# - Mining Support Services & Equipment
# - Miscellaneous Educational Service Providers
# - Miscellaneous Fintech Infrastructure
# - Miscellaneous Specialty Retailers
# - Multiline Insurance & Brokers
# - Multiline Utilities
# - Natural Gas Utilities
# - Non-Alcoholic Beverages
# - Non-Gold Precious Metals & Minerals
# - Non-Paper Containers & Packaging
# - Office Equipment
# - Oil & Gas Drilling
# - Oil & Gas Exploration and Production
# - Oil & Gas Refining and Marketing
# - Oil & Gas Transportation Services
# - Oil Related Services and Equipment
# - Online Services
# - Paper Packaging
# - Paper Products
# - Passenger Transportation, Ground & Sea
# - Pension Funds
# - Personal Products
# - Personal Services
# - Pharmaceuticals
# - Phones & Handheld Devices
# - Professional & Business Education
# - Professional Information Services
# - Property & Casualty Insurance
# - Real Estate Rental, Development & Operations
# - Real Estate Services
# - Recreational Products
# - Reinsurance
# - Renewable Energy Equipment & Services
# - Renewable Fuels
# - Residential REITs
# - Restaurants & Bars
# - Schools, Colleges & Universities
# - Semiconductor Equipment & Testing
# - Semiconductors
# - Shipbuilding
# - Software
# - Specialized REITs
# - Specialty Chemicals
# - Specialty Mining & Metals
# - Textiles & Leather Goods
# - Tires & Rubber Products
# - Tobacco
# - Toys & Children's Products
# - UK Investment Trusts
# - Uranium
# - Water & Related Utilities
# - Wireless Telecommunications Services

# %%
# Export combined_df to Excel
combined_df.to_excel("2012_2023_US_ESG.xlsx", index=False)
